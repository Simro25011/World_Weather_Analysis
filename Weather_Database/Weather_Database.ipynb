# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50): #i % 50 means i  divided by 50
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | nizwa
# Processing Record 6 of Set 1 | san quintin
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | havoysund
# Processing Record 9 of Set 1 | yenagoa
# Processing Record 10 of Set 1 | tura
# Processing Record 11 of Set 1 | paciran
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | chimbote
# Processing Record 17 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | gold coast
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | ostrovnoy
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | mtwara
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | coahuayana
# Processing Record 27 of Set 1 | chunskiy
# Processing Record 28 of Set 1 | samarai
# Processing Record 29 of Set 1 | minden
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | longyan
# Processing Record 32 of Set 1 | sungaipenuh
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | kodinar
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | hermon
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | cheremukhovo
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | lagoa
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | fairbanks
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | zhigansk
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | dhidhdhoo
# Processing Record 49 of Set 1 | vulcan
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | murray
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | elizabeth city
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | aykhal
# Processing Record 12 of Set 2 | seoul
# Processing Record 13 of Set 2 | ledyard
# Processing Record 14 of Set 2 | taoudenni
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | guasdualito
# Processing Record 18 of Set 2 | russell
# Processing Record 19 of Set 2 | tuy hoa
# Processing Record 20 of Set 2 | caruray
# Processing Record 21 of Set 2 | batavia
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | jalu
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | pacific grove
# Processing Record 30 of Set 2 | gao
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | manokwari
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | darhan
# Processing Record 35 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | clinton
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | jablah
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | santa rosa
# Processing Record 44 of Set 2 | foam lake
# Processing Record 45 of Set 2 | zeya
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | rabo de peixe
# Processing Record 48 of Set 2 | bagli
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | lorengau
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | osypenko
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | dongzhen
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | korla
# Processing Record 8 of Set 3 | kwinana
# Processing Record 9 of Set 3 | mehamn
# Processing Record 10 of Set 3 | lagos
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | verkhnevilyuysk
# Processing Record 13 of Set 3 | abu samrah
# Processing Record 14 of Set 3 | ambon
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | saint-pierre
# Processing Record 19 of Set 3 | coffs harbour
# Processing Record 20 of Set 3 | chateau-thierry
# Processing Record 21 of Set 3 | jacqueville
# Processing Record 22 of Set 3 | marsh harbour
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | beloha
# Processing Record 26 of Set 3 | bonavista
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | aripuana
# Processing Record 29 of Set 3 | kainantu
# Processing Record 30 of Set 3 | anshun
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | luwingu
# Processing Record 34 of Set 3 | hovd
# Processing Record 35 of Set 3 | ambulu
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | brae
# Processing Record 41 of Set 3 | zhezkazgan
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | padang
# Processing Record 45 of Set 3 | sola
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | port alfred
# Processing Record 48 of Set 3 | kalmar
# Processing Record 49 of Set 3 | mizan teferi
# Processing Record 50 of Set 3 | kavaratti
# Processing Record 1 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 4 | mutoko
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | ilhabela
# Processing Record 7 of Set 4 | carmen
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | mackay
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | sirsa
# Processing Record 12 of Set 4 | madison
# Processing Record 13 of Set 4 | merauke
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | krasnoarmeysk
# Processing Record 17 of Set 4 | neuquen
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | norman wells
# Processing Record 20 of Set 4 | katherine
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | college
# Processing Record 24 of Set 4 | manyana
# Processing Record 25 of Set 4 | rio gallegos
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | ballina
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | ribeira brava
# Processing Record 31 of Set 4 | huarmey
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | quesnel
# Processing Record 36 of Set 4 | cartagena
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | pinawa
# Processing Record 40 of Set 4 | sao joao do piaui
# Processing Record 41 of Set 4 | eirunepe
# Processing Record 42 of Set 4 | aloleng
# Processing Record 43 of Set 4 | saint-augustin
# Processing Record 44 of Set 4 | kanigoro
# Processing Record 45 of Set 4 | carballo
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | manta
# Processing Record 48 of Set 4 | kenai
# Processing Record 49 of Set 4 | muisne
# Processing Record 50 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 5 | wanaka
# Processing Record 2 of Set 5 | umm lajj
# Processing Record 3 of Set 5 | sesheke
# Processing Record 4 of Set 5 | coos bay
# Processing Record 5 of Set 5 | ulaangom
# Processing Record 6 of Set 5 | manavalakurichi
# Processing Record 7 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 5 | deputatskiy
# Processing Record 9 of Set 5 | barranca
# Processing Record 10 of Set 5 | redmond
# Processing Record 11 of Set 5 | zemio
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | kieta
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | nacala
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 5 | qaanaaq
# Processing Record 22 of Set 5 | morehead
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | udachnyy
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | kallithea
# Processing Record 27 of Set 5 | susuman
# Processing Record 28 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | florida
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | rio pardo
# Processing Record 33 of Set 5 | chatakonda
# Processing Record 34 of Set 5 | praia da vitoria
# Processing Record 35 of Set 5 | simpang
# Processing Record 36 of Set 5 | kondopoga
# Processing Record 37 of Set 5 | san julian
# Processing Record 38 of Set 5 | guadalupe y calvo
# Processing Record 39 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 5 | kodiak
# Processing Record 41 of Set 5 | elat
# Processing Record 42 of Set 5 | hedaru
# Processing Record 43 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 44 of Set 5 | sterling
# Processing Record 45 of Set 5 | ornskoldsvik
# Processing Record 46 of Set 5 | morant bay
# Processing Record 47 of Set 5 | tilichiki
# Processing Record 48 of Set 5 | piacabucu
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | stamsund
# City not found. Skipping...
# Processing Record 1 of Set 6 | cabo san lucas
# Processing Record 2 of Set 6 | rawson
# Processing Record 3 of Set 6 | srandakan
# Processing Record 4 of Set 6 | half moon bay
# Processing Record 5 of Set 6 | kuusamo
# Processing Record 6 of Set 6 | maicao
# Processing Record 7 of Set 6 | le port
# Processing Record 8 of Set 6 | pajarito
# Processing Record 9 of Set 6 | asyut
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | los llanos de aridane
# Processing Record 12 of Set 6 | banda aceh
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | beringovskiy
# Processing Record 15 of Set 6 | helena
# Processing Record 16 of Set 6 | viedma
# Processing Record 17 of Set 6 | conceicao do araguaia
# Processing Record 18 of Set 6 | laylay
# Processing Record 19 of Set 6 | maldonado
# Processing Record 20 of Set 6 | lavumisa
# Processing Record 21 of Set 6 | cap malheureux
# Processing Record 22 of Set 6 | preobrazheniye
# Processing Record 23 of Set 6 | port elizabeth
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | paamiut
# Processing Record 26 of Set 6 | port blair
# Processing Record 27 of Set 6 | raudeberg
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | karari
# Processing Record 30 of Set 6 | burica
# City not found. Skipping...
# Processing Record 31 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 6 | pestovo
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | orlik
# Processing Record 35 of Set 6 | kavieng
# Processing Record 36 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | spring hill
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | lampang
# Processing Record 40 of Set 6 | sangar
# Processing Record 41 of Set 6 | antsohihy
# Processing Record 42 of Set 6 | punto fijo
# Processing Record 43 of Set 6 | sibolga
# Processing Record 44 of Set 6 | awbari
# Processing Record 45 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 6 | manono
# Processing Record 47 of Set 6 | grants
# Processing Record 48 of Set 6 | tadine
# Processing Record 49 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 6 | wattwil
# Processing Record 1 of Set 7 | xinpu
# Processing Record 2 of Set 7 | walajapet
# Processing Record 3 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 7 | vanavara
# Processing Record 5 of Set 7 | saint anthony
# Processing Record 6 of Set 7 | hanzhong
# Processing Record 7 of Set 7 | porto novo
# Processing Record 8 of Set 7 | sitka
# Processing Record 9 of Set 7 | swan hill
# Processing Record 10 of Set 7 | bombay
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 7 | mareeba
# Processing Record 14 of Set 7 | kyzyl-suu
# Processing Record 15 of Set 7 | mirnyy
# Processing Record 16 of Set 7 | mitsamiouli
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | terrace bay
# Processing Record 19 of Set 7 | paraiso
# Processing Record 20 of Set 7 | dayong
# Processing Record 21 of Set 7 | devils lake
# Processing Record 22 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 7 | shipunovo
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | ostersund
# Processing Record 27 of Set 7 | nedjo
# Processing Record 28 of Set 7 | bethlehem
# Processing Record 29 of Set 7 | churumuco
# City not found. Skipping...
# Processing Record 30 of Set 7 | hofn
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | guerrero negro
# Processing Record 33 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 7 | arman
# Processing Record 35 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 7 | okha
# Processing Record 37 of Set 7 | ust-kan
# Processing Record 38 of Set 7 | acapulco
# Processing Record 39 of Set 7 | kyshtovka
# Processing Record 40 of Set 7 | kindu
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | miraflores
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | belaya gora
# Processing Record 45 of Set 7 | atuona
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | prachuap khiri khan
# Processing Record 48 of Set 7 | lavrentiya
# Processing Record 49 of Set 7 | anito
# Processing Record 50 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 8 | capitao poco
# Processing Record 2 of Set 8 | cabo rojo
# Processing Record 3 of Set 8 | chernyshevskiy
# Processing Record 4 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 8 | ust-maya
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | panaba
# Processing Record 9 of Set 8 | mayo
# Processing Record 10 of Set 8 | adilabad
# Processing Record 11 of Set 8 | boa vista
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | bara
# Processing Record 14 of Set 8 | honiara
# Processing Record 15 of Set 8 | tignapoloan
# City not found. Skipping...
# Processing Record 16 of Set 8 | shache
# Processing Record 17 of Set 8 | zambezi
# Processing Record 18 of Set 8 | olafsvik
# Processing Record 19 of Set 8 | nhulunbuy
# Processing Record 20 of Set 8 | shestakovo
# Processing Record 21 of Set 8 | hailar
# Processing Record 22 of Set 8 | mamlyutka
# Processing Record 23 of Set 8 | linkou
# Processing Record 24 of Set 8 | luderitz
# Processing Record 25 of Set 8 | cidreira
# Processing Record 26 of Set 8 | oktyabrskiy
# Processing Record 27 of Set 8 | maragogi
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | bang saphan
# Processing Record 30 of Set 8 | homer
# Processing Record 31 of Set 8 | hays
# Processing Record 32 of Set 8 | phalia
# Processing Record 33 of Set 8 | itoman
# Processing Record 34 of Set 8 | hami
# Processing Record 35 of Set 8 | russellville
# Processing Record 36 of Set 8 | panama city
# Processing Record 37 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 38 of Set 8 | oistins
# Processing Record 39 of Set 8 | townsville
# Processing Record 40 of Set 8 | fallon
# Processing Record 41 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 8 | marovoay
# Processing Record 43 of Set 8 | paita
# Processing Record 44 of Set 8 | boende
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | massaguet
# Processing Record 47 of Set 8 | kirgiz-miyaki
# Processing Record 48 of Set 8 | pueblo
# Processing Record 49 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 8 | kaduqli
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | vardo
# Processing Record 3 of Set 9 | cloquet
# Processing Record 4 of Set 9 | maumere
# Processing Record 5 of Set 9 | sistranda
# Processing Record 6 of Set 9 | foumban
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | namibe
# Processing Record 9 of Set 9 | owensboro
# Processing Record 10 of Set 9 | smithers
# Processing Record 11 of Set 9 | corsicana
# Processing Record 12 of Set 9 | lubawa
# Processing Record 13 of Set 9 | oshawa
# Processing Record 14 of Set 9 | souillac
# Processing Record 15 of Set 9 | meulaboh
# Processing Record 16 of Set 9 | kysyl-syr
# Processing Record 17 of Set 9 | adamas
# Processing Record 18 of Set 9 | debica
# Processing Record 19 of Set 9 | emba
# Processing Record 20 of Set 9 | porbandar
# Processing Record 21 of Set 9 | sabana de torres
# Processing Record 22 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 9 | pemba
# Processing Record 24 of Set 9 | nouadhibou
# Processing Record 25 of Set 9 | digha
# Processing Record 26 of Set 9 | makaryev
# Processing Record 27 of Set 9 | diebougou
# Processing Record 28 of Set 9 | gat
# Processing Record 29 of Set 9 | arkhara
# Processing Record 30 of Set 9 | port hawkesbury
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | haines junction
# Processing Record 33 of Set 9 | nago
# Processing Record 34 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 9 | birao
# Processing Record 36 of Set 9 | fez
# Processing Record 37 of Set 9 | ossora
# Processing Record 38 of Set 9 | tiksi
# Processing Record 39 of Set 9 | trinidad
# Processing Record 40 of Set 9 | kindersley
# Processing Record 41 of Set 9 | toowoomba
# Processing Record 42 of Set 9 | huilong
# Processing Record 43 of Set 9 | alyangula
# Processing Record 44 of Set 9 | san jeronimo
# Processing Record 45 of Set 9 | faya
# Processing Record 46 of Set 9 | sorong
# Processing Record 47 of Set 9 | ocala
# Processing Record 48 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 9 | cururupu
# Processing Record 50 of Set 9 | alekseyevsk
# Processing Record 1 of Set 10 | hirado
# Processing Record 2 of Set 10 | bereda
# Processing Record 3 of Set 10 | port-gentil
# Processing Record 4 of Set 10 | northam
# Processing Record 5 of Set 10 | bilma
# Processing Record 6 of Set 10 | salalah
# Processing Record 7 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 10 | parry sound
# Processing Record 9 of Set 10 | ellensburg
# Processing Record 10 of Set 10 | muros
# Processing Record 11 of Set 10 | te anau
# Processing Record 12 of Set 10 | dongkan
# Processing Record 13 of Set 10 | acarau
# Processing Record 14 of Set 10 | ruidoso
# Processing Record 15 of Set 10 | sokur
# Processing Record 16 of Set 10 | pingzhuang
# Processing Record 17 of Set 10 | escarcega
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | kitimat
# Processing Record 20 of Set 10 | paso de carrasco
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | puerto suarez
# Processing Record 23 of Set 10 | mayumba
# Processing Record 24 of Set 10 | sawakin
# Processing Record 25 of Set 10 | hoquiam
# Processing Record 26 of Set 10 | ocampo
# Processing Record 27 of Set 10 | cayenne
# Processing Record 28 of Set 10 | warman
# Processing Record 29 of Set 10 | yambio
# Processing Record 30 of Set 10 | anloga
# Processing Record 31 of Set 10 | kiama
# Processing Record 32 of Set 10 | cockburn town
# Processing Record 33 of Set 10 | finschhafen
# Processing Record 34 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 10 | moerai
# Processing Record 36 of Set 10 | corning
# Processing Record 37 of Set 10 | ban nahin
# Processing Record 38 of Set 10 | opatija
# Processing Record 39 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | agadez
# Processing Record 42 of Set 10 | mitu
# Processing Record 43 of Set 10 | alta floresta
# Processing Record 44 of Set 10 | ojinaga
# Processing Record 45 of Set 10 | pemberton
# Processing Record 46 of Set 10 | batagay-alyta
# Processing Record 47 of Set 10 | emerald
# Processing Record 48 of Set 10 | yartsevo
# Processing Record 49 of Set 10 | gamba
# Processing Record 50 of Set 10 | palana
# Processing Record 1 of Set 11 | mesyagutovo
# Processing Record 2 of Set 11 | kumano
# Processing Record 3 of Set 11 | hambantota
# Processing Record 4 of Set 11 | high level
# Processing Record 5 of Set 11 | vestmannaeyjar
# Processing Record 6 of Set 11 | magan
# Processing Record 7 of Set 11 | buala
# Processing Record 8 of Set 11 | baijiantan
# Processing Record 9 of Set 11 | brokopondo
# Processing Record 10 of Set 11 | fengcheng
# Processing Record 11 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 11 | ciudad bolivar
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | chapais
# Processing Record 15 of Set 11 | takoradi
# Processing Record 16 of Set 11 | galesong
# Processing Record 17 of Set 11 | san francisco
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | polson
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | sabang
# Processing Record 22 of Set 11 | ewa beach
# Processing Record 23 of Set 11 | kemijarvi
# Processing Record 24 of Set 11 | spitsevka
# Processing Record 25 of Set 11 | lokosovo
# Processing Record 26 of Set 11 | pitimbu
# Processing Record 27 of Set 11 | savannakhet
# Processing Record 28 of Set 11 | aksha
# Processing Record 29 of Set 11 | west lafayette
# Processing Record 30 of Set 11 | nueva loja
# Processing Record 31 of Set 11 | tymovskoye
# Processing Record 32 of Set 11 | islahiye
# Processing Record 33 of Set 11 | dakar
# Processing Record 34 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 35 of Set 11 | spornoye
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | darab
# Processing Record 38 of Set 11 | coihaique
# Processing Record 39 of Set 11 | williston
# Processing Record 40 of Set 11 | maceio
# Processing Record 41 of Set 11 | la rioja
# Processing Record 42 of Set 11 | klyuchi
# Processing Record 43 of Set 11 | mannarakkat
# Processing Record 44 of Set 11 | goderich
# Processing Record 45 of Set 11 | wajir
# Processing Record 46 of Set 11 | oksfjord
# Processing Record 47 of Set 11 | ipixuna
# Processing Record 48 of Set 11 | la ronge
# Processing Record 49 of Set 11 | qixia
# Processing Record 50 of Set 11 | ponta do sol
# Processing Record 1 of Set 12 | zhaotong
# Processing Record 2 of Set 12 | ohara
# Processing Record 3 of Set 12 | kutum
# Processing Record 4 of Set 12 | hilton head island
# Processing Record 5 of Set 12 | hope
# Processing Record 6 of Set 12 | bhakkar
# Processing Record 7 of Set 12 | sambava
# Processing Record 8 of Set 12 | uyuni
# Processing Record 9 of Set 12 | houma
# Processing Record 10 of Set 12 | san miguel
# Processing Record 11 of Set 12 | siocon
# Processing Record 12 of Set 12 | ternate
# Processing Record 13 of Set 12 | jieshi
# Processing Record 14 of Set 12 | alofi
# Processing Record 15 of Set 12 | ayutla
# Processing Record 16 of Set 12 | marzuq
# Processing Record 17 of Set 12 | gilbues
# Processing Record 18 of Set 12 | yen bai
# Processing Record 19 of Set 12 | dukat
# Processing Record 20 of Set 12 | new scone
# Processing Record 21 of Set 12 | kedrovyy
# Processing Record 22 of Set 12 | ketchikan
# Processing Record 23 of Set 12 | vzmorye
# Processing Record 24 of Set 12 | tigil
# Processing Record 25 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 12 | presidencia roque saenz pena
# Processing Record 27 of Set 12 | moranbah
# Processing Record 28 of Set 12 | atka
# City not found. Skipping...
# Processing Record 29 of Set 12 | lakatoro
# Processing Record 30 of Set 12 | miri
# Processing Record 31 of Set 12 | riyadh
# Processing Record 32 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 12 | havelock
# Processing Record 34 of Set 12 | west wendover
# Processing Record 35 of Set 12 | broome
# Processing Record 36 of Set 12 | altamira
# Processing Record 37 of Set 12 | marrakesh
# Processing Record 38 of Set 12 | yerofey pavlovich
# Processing Record 39 of Set 12 | gorontalo
# Processing Record 40 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 12 | yerbogachen
# Processing Record 42 of Set 12 | yeniseysk
# Processing Record 43 of Set 12 | jacareacanga
# Processing Record 44 of Set 12 | makat
# Processing Record 45 of Set 12 | bama
# Processing Record 46 of Set 12 | taber
# Processing Record 47 of Set 12 | nantucket
# Processing Record 48 of Set 12 | daru
# Processing Record 49 of Set 12 | humaita
# Processing Record 50 of Set 12 | margate
# Processing Record 1 of Set 13 | honningsvag
# Processing Record 2 of Set 13 | novaya malykla
# Processing Record 3 of Set 13 | kargasok
# Processing Record 4 of Set 13 | puri
# Processing Record 5 of Set 13 | belomorsk
# Processing Record 6 of Set 13 | glossa
# Processing Record 7 of Set 13 | bodo
# Processing Record 8 of Set 13 | berlevag
# Processing Record 9 of Set 13 | sirari
# Processing Record 10 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | garowe
# Processing Record 12 of Set 13 | coxim
# Processing Record 13 of Set 13 | madang
# Processing Record 14 of Set 13 | havre-saint-pierre
# Processing Record 15 of Set 13 | gazojak
# Processing Record 16 of Set 13 | wanxian
# Processing Record 17 of Set 13 | okhotsk
# Processing Record 18 of Set 13 | turki
# Processing Record 19 of Set 13 | rzeszow
# Processing Record 20 of Set 13 | eureka
# Processing Record 21 of Set 13 | launceston
# Processing Record 22 of Set 13 | veisiejai
# Processing Record 23 of Set 13 | san rafael del sur
# Processing Record 24 of Set 13 | sovetskiy
# Processing Record 25 of Set 13 | minokamo
# Processing Record 26 of Set 13 | mwense
# Processing Record 27 of Set 13 | biltine
# Processing Record 28 of Set 13 | vite
# Processing Record 29 of Set 13 | almunecar
# Processing Record 30 of Set 13 | along
# Processing Record 31 of Set 13 | vernon
# Processing Record 32 of Set 13 | labuhan
# Processing Record 33 of Set 13 | onguday
# Processing Record 34 of Set 13 | parchim
# Processing Record 35 of Set 13 | lobva
# Processing Record 36 of Set 13 | andijon
# Processing Record 37 of Set 13 | tambovka
# Processing Record 38 of Set 13 | agustin codazzi
# Processing Record 39 of Set 13 | bamnet narong
# Processing Record 40 of Set 13 | yuancheng
# Processing Record 41 of Set 13 | ranipur
# Processing Record 42 of Set 13 | cavalcante
# Processing Record 43 of Set 13 | jumla
# Processing Record 44 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 13 | miloslavskoye
# Processing Record 46 of Set 13 | vestmanna
# Processing Record 47 of Set 13 | monrovia
# Processing Record 48 of Set 13 | alvinopolis
# Processing Record 49 of Set 13 | bosaso
# Processing Record 50 of Set 13 | qaqortoq
# Processing Record 1 of Set 14 | pemangkat
# Processing Record 2 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 3 of Set 14 | wum
# Processing Record 4 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 14 | gerash
# Processing Record 6 of Set 14 | cabral
# Processing Record 7 of Set 14 | koceljeva
# Processing Record 8 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | kota kinabalu
# Processing Record 10 of Set 14 | yokadouma
# Processing Record 11 of Set 14 | mashhad
# Processing Record 12 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 13 of Set 14 | palmer
# Processing Record 14 of Set 14 | bayji
# Processing Record 15 of Set 14 | kolda
# Processing Record 16 of Set 14 | kaeo
# Processing Record 17 of Set 14 | bristol
# Processing Record 18 of Set 14 | riohacha
# Processing Record 19 of Set 14 | casablanca
# Processing Record 20 of Set 14 | lebowakgomo
# Processing Record 21 of Set 14 | atoyac
# Processing Record 22 of Set 14 | bam
# Processing Record 23 of Set 14 | turukhansk
# Processing Record 24 of Set 14 | ambovombe
# Processing Record 25 of Set 14 | tautira
# Processing Record 26 of Set 14 | imeni poliny osipenko
# Processing Record 27 of Set 14 | puerto leguizamo
# Processing Record 28 of Set 14 | taga
# Processing Record 29 of Set 14 | bendigo
# Processing Record 30 of Set 14 | storozhevaya
# Processing Record 31 of Set 14 | nalut
# Processing Record 32 of Set 14 | saposoa
# Processing Record 33 of Set 14 | guamuchil
# Processing Record 34 of Set 14 | wladyslawowo
# Processing Record 35 of Set 14 | cam ranh
# Processing Record 36 of Set 14 | sitia
# Processing Record 37 of Set 14 | beira
# Processing Record 38 of Set 14 | axim
# Processing Record 39 of Set 14 | teguise
# Processing Record 40 of Set 14 | waipawa
# Processing Record 41 of Set 14 | castelldefels
# Processing Record 42 of Set 14 | araouane
# Processing Record 43 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 14 | tuatapere
# Processing Record 45 of Set 14 | atambua
# Processing Record 46 of Set 14 | boa esperanca do sul
# Processing Record 47 of Set 14 | dom pedro
# Processing Record 48 of Set 14 | chumikan
# Processing Record 49 of Set 14 | lima
# Processing Record 50 of Set 14 | pochutla
# Processing Record 1 of Set 15 | koboldo
# City not found. Skipping...
# Processing Record 2 of Set 15 | tinyahuarco
# Processing Record 3 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 4 of Set 15 | iquique
# Processing Record 5 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 15 | naral
# City not found. Skipping...
# Processing Record 7 of Set 15 | hammerfest
# Processing Record 8 of Set 15 | vostok
# Processing Record 9 of Set 15 | kruisfontein
# Processing Record 10 of Set 15 | tanggu
# Processing Record 11 of Set 15 | lakes entrance
# Processing Record 12 of Set 15 | dickinson
# Processing Record 13 of Set 15 | kiunga
# Processing Record 14 of Set 15 | san vicente
# Processing Record 15 of Set 15 | fuxin
# Processing Record 16 of Set 15 | voh
# Processing Record 17 of Set 15 | adrar
# Processing Record 18 of Set 15 | linqiong
# Processing Record 19 of Set 15 | de-kastri
# Processing Record 20 of Set 15 | manaure
# Processing Record 21 of Set 15 | aksarka
# Processing Record 22 of Set 15 | flinders
# Processing Record 23 of Set 15 | southbridge
# Processing Record 24 of Set 15 | lensk
# Processing Record 25 of Set 15 | batouri
# Processing Record 26 of Set 15 | mahon
# Processing Record 27 of Set 15 | petrivka
# Processing Record 28 of Set 15 | ziezmariai
# Processing Record 29 of Set 15 | surat thani
# Processing Record 30 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 15 | glenwood springs
# Processing Record 32 of Set 15 | san carlos de bariloche
# Processing Record 33 of Set 15 | mantua
# Processing Record 34 of Set 15 | port macquarie
# Processing Record 35 of Set 15 | tiruchchendur
# Processing Record 36 of Set 15 | shingu
# Processing Record 37 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 15 | grand-lahou
# Processing Record 39 of Set 15 | grand gaube
# Processing Record 40 of Set 15 | warrington
# Processing Record 41 of Set 15 | mackenzie
# Processing Record 42 of Set 15 | yarmouth
# Processing Record 43 of Set 15 | zharkent
# Processing Record 44 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 45 of Set 15 | abu kamal
# Processing Record 46 of Set 15 | mabaruma
# Processing Record 47 of Set 15 | zyryanka
# Processing Record 48 of Set 15 | kangaatsiaq
# Processing Record 49 of Set 15 | namatanai
# Processing Record 50 of Set 15 | junin
# Processing Record 1 of Set 16 | urumqi
# Processing Record 2 of Set 16 | wagar
# Processing Record 3 of Set 16 | ormara
# Processing Record 4 of Set 16 | port augusta
# Processing Record 5 of Set 16 | nkan
# Processing Record 6 of Set 16 | bontang
# Processing Record 7 of Set 16 | pierre
# Processing Record 8 of Set 16 | surt
# Processing Record 9 of Set 16 | solnechnyy
# Processing Record 10 of Set 16 | yarensk
# Processing Record 11 of Set 16 | asfi
# Processing Record 12 of Set 16 | mnogovershinnyy
# Processing Record 13 of Set 16 | takob
# City not found. Skipping...
# Processing Record 14 of Set 16 | andilamena
# Processing Record 15 of Set 16 | aswan
# Processing Record 16 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 16 | fort nelson
# Processing Record 18 of Set 16 | zhumadian
# Processing Record 19 of Set 16 | qabaqcol
# Processing Record 20 of Set 16 | hervey bay
# Processing Record 21 of Set 16 | christchurch
# Processing Record 22 of Set 16 | skagen
# Processing Record 23 of Set 16 | usinsk
# Processing Record 24 of Set 16 | port lincoln
# Processing Record 25 of Set 16 | tigre
# Processing Record 26 of Set 16 | nicoya
# Processing Record 27 of Set 16 | aasiaat
# Processing Record 28 of Set 16 | senneterre
# Processing Record 29 of Set 16 | vila
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     34.81        68           2
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     75.06        73          75
# 2          Rikitea      PF -23.1203 -134.9692     72.59        80         100
# 3            Nizwa      OM  22.9333   57.5333     96.55        29          83
# 4      San Quintin      MX  30.4833 -115.9500     77.31        69          56
# 5       Chokurdakh      RU  70.6333  147.9167     56.19        43          99
# 6        Havoysund      NO  70.9963   24.6622     52.03        87         100
# 7          Yenagoa      NG   4.9247    6.2642     76.30        86         100
# 8             Tura      IN  25.5198   90.2201     75.45        96          28
# 9          Paciran      ID  -6.8767  112.3761     77.68        83          56
#
#    Wind Speed      Current Description
# 0       17.60                clear sky
# 1        3.44  light intensity drizzle
# 2       27.94               light rain
# 3        6.31            broken clouds
# 4        8.48            broken clouds
# 5        5.68          overcast clouds
# 6       18.07          overcast clouds
# 7        6.58               light rain
# 8        6.33         scattered clouds
# 9        7.23            broken clouds

# %%
len(city_data_df)
# Out:
# 709

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
